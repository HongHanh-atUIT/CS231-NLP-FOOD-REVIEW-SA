# %%
import torch
import pandas as pd
import numpy as np
from torch.utils.data import Dataset, DataLoader
from transformers import AutoModel, AutoTokenizer
from transformers import get_linear_schedule_with_warmup
from torch.optim import AdamW
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score, accuracy_score
from tqdm import tqdm
import warnings
import time
warnings.filterwarnings('ignore')

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# # Dataset

# %%
data = pd.read_csv("Dataset/vsa_food_rv_train_clean.csv", encoding="utf-8")
X = data["Comment"]
y = data["Rating"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=2020, test_size=0.2, stratify=y
)
X_train = X_train.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

print(f"Train size: {len(X_train)}, Test size: {len(X_test)}")
# Out:
# Train size: 10326, Test size: 2582

# %% [markdown]
# # PhoBERT Dataset Definition

# %%
class PhoBERTDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=256):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len
    
    def __len__(self):
        return len(self.texts)
    
    def __getitem__(self, idx):
        text = str(self.texts.iloc[idx])
        label = self.labels.iloc[idx]
        
        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt'
        )
        
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(label, dtype=torch.long)
        }

# %% [markdown]
# # PhoBERT-based Classification Model

# %%
class PhoBERTClassifier(torch.nn.Module):
    def __init__(self, n_classes=2, dropout=0.2):
        super().__init__()
        self.bert = AutoModel.from_pretrained("vinai/phobert-base-v2")
        self.drop = torch.nn.Dropout(dropout)
        self.fc = torch.nn.Linear(768, n_classes)

    def forward(self, input_ids, attention_mask):
        last_hidden_state, pooled_output = self.bert(
            input_ids=input_ids,
            attention_mask=attention_mask,
            return_dict=False
        )
        x = self.drop(pooled_output)
        logits = self.fc(x)

        return logits

# %%
def train_epoch(model, data_loader, loss_fn, optimizer, scheduler, device):
    model.train()
    losses = []
    correct_predictions = 0
    
    for batch in tqdm(data_loader, desc="Training"):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)
        
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        _, preds = torch.max(outputs, dim=1)
        loss = loss_fn(outputs, labels)
        
        correct_predictions += torch.sum(preds == labels)
        losses.append(loss.item())
        
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        scheduler.step()
        optimizer.zero_grad()
    
    return correct_predictions.double() / len(data_loader.dataset), np.mean(losses)

# %%
def eval_model(model, data_loader, loss_fn, device):
    model.eval()
    losses = []
    correct_predictions = 0
    predictions = []
    true_labels = []
    
    with torch.no_grad():
        for batch in tqdm(data_loader, desc="Evaluating"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)
            
            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            _, preds = torch.max(outputs, dim=1)
            loss = loss_fn(outputs, labels)
            
            correct_predictions += torch.sum(preds == labels)
            losses.append(loss.item())
            
            predictions.extend(preds.cpu().numpy())
            true_labels.extend(labels.cpu().numpy())
    
    return (correct_predictions.double() / len(data_loader.dataset), 
            np.mean(losses), predictions, true_labels)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base-v2")

MAX_LEN = 256
BATCH_SIZE = 16
EPOCHS = 3
LEARNING_RATE = 2e-5

train_dataset = PhoBERTDataset(X_train, y_train, tokenizer, MAX_LEN)
test_dataset = PhoBERTDataset(X_test, y_test, tokenizer, MAX_LEN)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
model = PhoBERTClassifier(n_classes=2, dropout=0.3)
model = model.to(device)

class_counts = y_train.value_counts().sort_index()
class_weights = 1.0 / class_counts
class_weights = class_weights / class_weights.sum()
class_weights = torch.FloatTensor(class_weights.values).to(device)

loss_fn = torch.nn.CrossEntropyLoss(weight=class_weights)
optimizer = AdamW(model.parameters(), lr=LEARNING_RATE)

total_steps = len(train_loader) * EPOCHS
scheduler = get_linear_schedule_with_warmup(
    optimizer,
    num_warmup_steps=0,
    num_training_steps=total_steps
)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at vinai/phobert-base-v2 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # Training

# %%
import os

history = {
    'train_acc': [],
    'train_loss': [],
    'val_acc': [],
    'val_loss': []
}

best_accuracy = 0
start_time = time.time()

for epoch in range(EPOCHS):
    print(f'\nEpoch {epoch + 1}/{EPOCHS}')
    print('-' * 50)
    
    train_acc, train_loss = train_epoch(
        model, train_loader, loss_fn, optimizer, scheduler, device
    )
    
    print(f'Train loss: {train_loss:.4f} - Train accuracy: {train_acc:.4f}')
    
    val_acc, val_loss, _, _ = eval_model(model, test_loader, loss_fn, device)
    
    print(f'Val loss: {val_loss:.4f} - Val accuracy: {val_acc:.4f}')
    
    history['train_acc'].append(train_acc.item())
    history['train_loss'].append(train_loss)
    history['val_acc'].append(val_acc.item())
    history['val_loss'].append(val_loss)
    
    if val_acc > best_accuracy:
        os.makedirs("Model", exist_ok=True)
        torch.save(model.state_dict(), 'Model/phobert_best_notpooling.pth')
        best_accuracy = val_acc
        print(f'Model saved with accuracy: {best_accuracy:.4f}')

end_time = time.time()
print(f"\n*** Training hoàn tất sau {(end_time - start_time):.2f}s ***")
# Out:
# Epoch 1/3
# --------------------------------------------------
# Training: 100%|██████████| 646/646 [23:05<00:00,  2.15s/it]
# Train loss: 0.3664 - Train accuracy: 0.8964
# Evaluating: 100%|██████████| 162/162 [00:35<00:00,  4.52it/s]
# Val loss: 0.3549 - Val accuracy: 0.9171
# Model saved with accuracy: 0.9171
#
# Epoch 2/3
# --------------------------------------------------
# Training: 100%|██████████| 646/646 [23:04<00:00,  2.14s/it]
# Train loss: 0.2672 - Train accuracy: 0.9366
# Evaluating: 100%|██████████| 162/162 [00:35<00:00,  4.53it/s]
# Val loss: 0.3148 - Val accuracy: 0.9214
# Model saved with accuracy: 0.9214
#
# Epoch 3/3
# --------------------------------------------------
# Training: 100%|██████████| 646/646 [23:04<00:00,  2.14s/it]
# Train loss: 0.2278 - Train accuracy: 0.9517
# Evaluating: 100%|██████████| 162/162 [00:35<00:00,  4.53it/s]
# Val loss: 0.3634 - Val accuracy: 0.9253
# Model saved with accuracy: 0.9253
#
# *** Training hoàn tất sau 4267.03s ***

# %% [markdown]
# # Evaluation

# %%
model.load_state_dict(torch.load('Model/phobert_best_notpooling.pth'))
_, _, predictions, true_labels = eval_model(model, test_loader, loss_fn, device)
# Out:
# Evaluating: 100%|██████████| 162/162 [00:34<00:00,  4.69it/s]

# %%
print(classification_report(true_labels, predictions, target_names=['Negative', 'Positive']))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.89      0.81      0.85       657
#     Positive       0.94      0.97      0.95      1925
#
#     accuracy                           0.93      2582
#    macro avg       0.91      0.89      0.90      2582
# weighted avg       0.92      0.93      0.92      2582

# %%
accuracy = accuracy_score(true_labels, predictions)
f1 = f1_score(true_labels, predictions, average='macro')
print(f"\nAccuracy: {accuracy:.4f}")
print(f"F1-Score (macro): {f1:.4f}")
# Out:
# Accuracy: 0.9253
# F1-Score (macro): 0.8983

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

cm = confusion_matrix(true_labels, predictions)

def plot_confusion_matrix(cm, class_names):
    plt.figure(figsize=(6, 5))
    plt.imshow(cm, cmap=plt.cm.Blues)
    plt.title("Confusion Matrix")
    plt.colorbar()
    
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names)
    plt.yticks(tick_marks, class_names)

    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(
                j, i, cm[i, j],
                horizontalalignment="center",
                verticalalignment="center",
                color="white" if cm[i, j] > cm.max() / 2 else "black",
                fontsize=12
            )

    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")
    plt.tight_layout()
    plt.show()

plot_confusion_matrix(cm, ['Negative', 'Positive'])

# %% [markdown]
# # Misclassified samples

# %%
error_df = pd.DataFrame({
    "text": X_test,
    "true_label": true_labels,
    "pred_label": predictions
})

label_map = {0: "Negative", 1: "Positive"}
error_df["true_label_name"] = error_df["true_label"].map(label_map)
error_df["pred_label_name"] = error_df["pred_label"].map(label_map)

misclassified = error_df[error_df["true_label"] != error_df["pred_label"]]

print(f"\nTổng số câu dự đoán sai: {len(misclassified)} / {len(X_test)}")
# Out:
# Tổng số câu dự đoán sai: 193 / 2582

# %%
false_positive = misclassified[
    (misclassified["true_label"] == 0) &
    (misclassified["pred_label"] == 1)
]

print(f"\nNegative → Positive (False Positive): {len(false_positive)} câu\n")

for i, row in false_positive.head(20).iterrows():  
    print("Text:", row["text"])
    print("True:", row["true_label_name"], 
          "| Pred:", row["pred_label_name"])
    print("-" * 120)
# Out:
# Negative → Positive (False Positive): 127 câu
#
# Text: emj_sparkles địa điểm mọi người chú ý là ngõ hàng cháo chứ không phải phố hàng cháo bên cạnh nha ngay gần nhà số 6 mà cô bán ngay vỉa hè luôn ý )) vào là nhìn thấy luôn nhé emj_sparkles không gian ngồi ngắm khí giời ăn hoặc mang về emj_sparkles đồ ăn hot lâu rồi nhưng chưa ăn thử cái món này bao giờ )) đặc biệt là mình lại không chọn lặn lội lên phố cổ để ăn thử mình chọn quán nhỏ nhỏ ở nơi chẳng mấy ai biết thế này thôi đầu tiên chọc thử cái vỏ nếp nướng lúc ở trên vỉ qu
# True: Negative | Pred: Positive
# ------------------------------------------------------------------------------------------------------------------------
# Text: quán đăng ảnh pizza nữ hoàng đẹp lồng lộn thế này mà bánh mang về như này ạ quán có cần khuếch đại đến vậy không ? giao hàng được cái nhanh ăn thì hết sức biết !
# True: Negative | Pred: Positive
# ------------------------------------------------------------------------------------------------------------------------
# Text: bánh mỳ sài gòn 35 ngàn full nhân được hẳn 1 miếng như jambon 2 miếng chả 2~3 miếng luộc (hấp/rán ? ) nói chung không gọi là bánh mỳ sài gòn được vị thì chả có gì ấn tượng sẽ không ăn lại vì với 35 ngàn sẽ mua được bánh ở nhiều chỗ ngon hơn
# True: Negative | Pred: Positive
# ------------------------------------------------------------------------------------------------------------------------
# Text: hôm nay mình với bạn đi ăn trưa ở bbq giảng võ quán khá đông khách sạch sẽ mát mẻ dễ tìm thế nhưng thái độ của bạn nhân viên phục vụ mình không tốt cho lắm mặt lạnh te hầm hầm kiểu như khó chịu với khách hàng í làm mất điểm của quán còn về đồ ăn bọn mình gọi 1 giâyet gà truyền thống 1 set cơm bbq 1 pizza nhiệt đới gà ăn bình thường hơi ngấy cơm tạm được pizza khá nhiều phô mai nói chung là ok
# True: Negative | Pred: Positive
# ------------------------------------------------------------------------------------------------------------------------

# %%
false_negative = misclassified[
    (misclassified["true_label"] == 1) &
    (misclassified["pred_label"] == 0)
]

print(f"\nPositive → Negative (False Negative): {len(false_negative)} câu\n")

for i, row in false_negative.head(20).iterrows(): 
    print("Text:", row["text"])
    print("True:", row["true_label_name"], 
          "| Pred:", row["pred_label_name"])
    print("-" * 120)
# Out:
# Positive → Negative (False Negative): 66 câu
#
# Text: chưa bao giờ ăn cốc chè nào mà thấy tệ như thế này !! mình gọi sữa chua mít và chè thái mít không giống chút nào với hình ảnh quán cung cấp chè thái mít thì nồng mùi dừa ăn quá gẫy luôn phải đi đặt luôn sang quán khác
# True: Positive | Pred: Negative
# ------------------------------------------------------------------------------------------------------------------------
# Text: 9 giờ tối thứ 4 qua quán đã đóng cửa chắc do trời mưa
# True: Positive | Pred: Negative
# ------------------------------------------------------------------------------------------------------------------------
# Text: mình có order về nhà ăn combo gồm có 2 miếng gà 1 pepsi 1 bắp cải trộn gà ăn thì khô pepsi cũng không lạnh như mọi khi món bắp cải trộn thì như cho heo ăn ý vừa khô vừa không có sốt ăn nhạt nhẽo không thể nhuốt nổi rất mong quán cải thiện lại chất lượng đồ ăn
# True: Positive | Pred: Negative
# ------------------------------------------------------------------------------------------------------------------------
# Text: quán sạch sẽ thoáng mát khá dễ tìm nhân viên quán phục vụ khá tốt và ổn buffet ở đây bình thường vừa túi tiền cho sinh viên đi ăn nướng hay lẩu thì phần nước chấm chiếm 70% độ ngon rồi nhưng nước chấm ở đây chán quá nên làm nướng cũng mất ngon khoai tây chiên ở đây hôm mình ăn thì hơi ỉu thịt cũng không ngon lắm hải sản cũng bình thường lúc cuối ăn tráng miệng gọi chè ngô thì ôi giời ôi cái bát chè ngô chỉ to hơn chén uống trà một tí ăn cốc chè không bõ dính răng điểm gỡ gạc duy nhất là bánh xèo khá ngon à salad nữa
# True: Positive | Pred: Negative
# ------------------------------------------------------------------------------------------------------------------------
# Text: bánh mì thịt nướng mà thịt trắng không khác gì thịt luộc luôn nhân bánh ít sốt cũng ít nói chung chả có mấy
# True: Positive | Pred: Negative
# ------------------------------------------------------------------------------------------------------------------------
# Text: mình order trà sữa không đường nhưng ngọt quá không thể uống được mong các bạn làm việc tập trung hơn
# True: Positive | Pred: Negative
# ------------------------------------------------------------------------------------------------------------------------
# Text: nhân viên bảo vệ không sắp xếp xe của khách thẳng hàng lối đứng chỉ tay bảo khách đỗ không hỗ trợ khách lấy xe dù lấy vé nhưng lại nhắc khoá cổ không hiểu nhiệm vụ của bảo vệ nhà hàng này làm gì mình đến vài lần rồi nhưng không lần nào thấy cải thiện đồ ăn ổn và mức giá phù hợp
# True: Positive | Pred: Negative
# ------------------------------------------------------------------------------------------------------------------------
# Text
# True: Positive | Pred: Negative
# ------------------------------------------------------------------------------------------------------------------------
# Text: sụn khá đắt cả 2 được nhưng sụn khó ăn lần sau chắc chỉ gọi thịt nướng chai tương ớt cực kỳ bẩn không nên ăn tương ớt mong các công đoạn khác của quán sạch đẹp
# True: Positive | Pred: Negative
# ------------------------------------------------------------------------------------------------------------------------
# Text: quán bình thường vừa ngon vừa rẻ thích quán nên giới thiệu bạn đến ăn ai dè lại có biến emj_disappointed_face emj_disappointed_face emj_disappointed_face qua quán đúng lúc quán đông đợi lâu lâu mới có đồ bác chủ tay chân luống cuống còn làm xót đồ cà phê cho vào caramen thập cẩm và caramen sữa chua bị quá tay ăn thành ra mất ngon emj_sad_but_relieved_face quán hôm đó có bác phụ việc mới có lẽ chưa quen nên không giúp được gì nhiều bác chủ thành ra nhiều việc khách đông bác chạy qua chạy lại hoài cũng thương bác )) mong lần tới quay lại quán lấy lại chất lượng như cũ ))
# True: Positive | Pred: Negative
# ------------------------------------------------------------------------------------------------------------------------
# Text: bình thường mình lười toàn đi ngầm đọc đọc gì viu chứ chả vote vủng bao giờ thương quán ngon mà bị quả 3 điểm bên trên làm bao người hiểu lầm emj_face_with_rolling_eyes nên mới lon ton vào vote nhemm nhemm emj_drooling_face
# True: Positive | Pred: Negative
# ------------------------------------------------------------------------------------------------------------------------
# Text: nọi người nhìn ảnh sẽ hiểu ạ ếch ở đây thực sự rất ngon nhưng cháo thì cực tệ
# True: Positive | Pred: Negative
# ------------------------------------------------------------------------------------------------------------------------
# Text: chất lượng đồ ăn thì ok nhưng thực sự không hài lòng về phục vụ đợi 30 phút để được đĩa này định đứng lên đi về thì mới bê ra lần 1 gọi món 5 phút sau báo tất cả các món mình gọi đều hết ok thông cảm vì mình đi giờ trưa bị đông gọi lại món thì hỏi 5 món hết cả năm gọi chốt lại hai món thì ngồi chờ xong mấy phút sau lại được độ ba nhân viên ra hỏi chị gọi món gì ý nhỉ thanh toán tiền thì nhận tiền xong cảm ơn rồi quên luôn trả lại tiền thừa nhân viên đứng nói chuyện với các bạn khác và mình lại phải đi hỏi tiền thừa (thừa tiền chẵn lắm nên không phải không có tiền lẻ chờ đổi gì nhé mà là quên luôn)
# True: Positive | Pred: Negative
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Train & Val loss

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history['train_acc'], label='Train Accuracy')
plt.plot(history['val_acc'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history['train_loss'], label='Train Loss')
plt.plot(history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Sample

# %%
def predict_sentiment(text, model, tokenizer, device, max_len=256):
    model.eval()
    encoding = tokenizer.encode_plus(
        text,
        add_special_tokens=True,
        max_length=max_len,
        padding='max_length',
        truncation=True,
        return_attention_mask=True,
        return_tensors='pt'
    )
    
    input_ids = encoding['input_ids'].to(device)
    attention_mask = encoding['attention_mask'].to(device)
    
    with torch.no_grad():
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        _, pred = torch.max(outputs, dim=1)
        probs = torch.nn.functional.softmax(outputs, dim=1)
    
    return pred.item(), probs[0].cpu().numpy()

# %%
test_texts = [
    "Món ăn rất ngon, tôi rất thích",
    "Đồ ăn dở tệ, không bao giờ quay lại nữa",
    "Bình thường, không có gì đặc biệt"
]

for text in test_texts:
    pred, probs = predict_sentiment(text, model, tokenizer, device)
    sentiment = "Positive" if pred == 1 else "Negative"
    print(f"\nText: {text}")
    print(f"Prediction: {sentiment}")
    print(f"Confidence: Negative={probs[0]:.3f}, Positive={probs[1]:.3f}")
# Out:
# Text: Món ăn rất ngon, tôi rất thích
# Prediction: Positive
# Confidence: Negative=0.035, Positive=0.965
#
# Text: Đồ ăn dở tệ, không bao giờ quay lại nữa
# Prediction: Negative
# Confidence: Negative=0.991, Positive=0.009
#
# Text: Bình thường, không có gì đặc biệt
# Prediction: Negative
# Confidence: Negative=0.701, Positive=0.299
